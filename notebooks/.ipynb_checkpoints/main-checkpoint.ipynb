# %%
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torchvision.models as models
import torchvision.transforms as transforms
import numpy as np
from scipy import ndimage
from PIL import Image
import matplotlib.pyplot as plt

# %%
VG = r'D:\Code\implementations\research\CV\Neural Style Transfer\assets\starrynight.jpg'
TRUMP = r'D:\Code\implementations\research\CV\Neural Style Transfer\assets\trump.jpg'
vg = Image.open(VG)
trump = Image.open(TRUMP)
device = torch.device('cuda')

# %%
np.random.seed(23)
torch.manual_seed(23)
if str(device) == 'cuda':
    torch.cuda.manual_seed(23)
    torch.cuda.manual_seed_all(23) 
    torch.backends.cudnn.deterministic = True 
    torch.backends.cudnn.benchmark = False

# %%
vgg19 = models.vgg19(pretrained=True)
vgg19
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
# ...

# %%
net = nn.Sequential(vgg19.features[:14])
net = net.eval().to(device)

# %%
net
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#   )
# )

# %%
t = transforms.Compose([
    transforms.Resize((256, 412)),
    transforms.ToTensor(),
])

# %%
G = np.random.uniform(0, 1, size = (256, 412, 3)).astype(np.float32)
G = ndimage.filters.median_filter(G, [8, 8, 1])

# %%
vg = t(vg)
trump = t(trump)

# %%
plt.imshow(transforms.ToPILImage()(trump))

# %%
plt.imshow(transforms.ToPILImage()(vg))

# %%
plt.imshow(G)

# %%
G = torch.from_numpy(G).permute(2, 0, 1).to(device)
G = Variable(G[None], requires_grad = True)

# %%
trump = Variable(trump[None], requires_grad = False).to(device)
vg = Variable(vg[None], requires_grad = False).to(device)

# %%
# Using Hooks
class SaveFeatures():
    features = None
    def __init__(self, module): self.hook = module.register_forward_hook(self.hook_fn)
    def hook_fn(self, module, input, output): self.features = output
    def close(self): self.hook.remove()

# %%
activations = [i for i, layer in enumerate(net[0]) if isinstance(layer, nn.Conv2d)]; activations
# Out:
# [0, 2, 5, 7, 10, 12]

# %%
def showContentChange():
    sf = SaveFeatures(list(net[0].children())[activations[-1]])    
    net(trump)
    trump_encoded = Variable(sf.features.clone(), requires_grad = True)
    optimizer = torch.optim.SGD([G], lr = 1e2)
    criterion = nn.MSELoss()
    for epoch in range(50):
        optimizer.zero_grad()
        net(G)
        G_encoded = sf.features
        loss = criterion(G_encoded, trump_encoded)
        loss.backward(retain_graph = True)
        optimizer.step()
        print(epoch, loss.item())
    sf.close()
    plt.imshow(transforms.ToPILImage()(G.cpu().detach()[0]))

# %%
def gramMatrix(A):
#     print(list(A.shape))
    b, c, h, w = A.shape
    A = A.view(b*c, -1)
    return torch.mm(A, A.T)

# %%
def showStyleChange():
    sfs = [SaveFeatures(list(net[0].children())[a]) for a in activations[:-2]]
    net(vg)
    vg_encoded = [Variable(sfi.features.clone(), requires_grad = True) for sfi in sfs]
#     print([tens.size() for tens in picasso_encoded])
    gram_picassso = [gramMatrix(tens) for tens in vg_encoded]
    optimizer = torch.optim.SGD([G], lr = 5e-8)
    criterion = nn.MSELoss()
    for epoch in range(5000):
        optimizer.zero_grad()
        net(G)
        G_gram = [gramMatrix(sfi.features) for sfi in sfs]
        loss = sum([criterion(g_grami, vg_grami) for g_grami, vg_grami in zip(G_gram, gram_vg)])
        loss.backward(retain_graph = True)
        optimizer.step()
        print(epoch, loss.item())
    [sf.close() for sf in sfs]
    plt.imshow(transforms.ToPILImage()(G.cpu().detach()[0]))

# %%
def styleTransfer():
    sf_content = SaveFeatures(list(net[0].children())[activations[-2]])    
    net(trump)
    trump_encoded = Variable(sf_content.features.clone(), requires_grad = True)
    sf_style = [SaveFeatures(list(net[0].children())[a]) for a in activations[1:-2]]

    net(picasso)
    vg_encoded = [Variable(sfi.features.clone(), requires_grad = True) for sfi in sf_style]
    gram_vg = [gramMatrix(tens) for tens in vg_encoded]

    optimizer = torch.optim.SGD([G], lr = 1e-7)
    criterion = nn.MSELoss()

    for epoch in range(1000):
        optimizer.zero_grad()
        net(G)
        G_encoded = sf_content.features
        content_loss = criterion(G_encoded, prithvi_encoded) * 1e9 
        G_gram = [gramMatrix(sfi.features) for sfi in sf_style]
        style_loss = sum([criterion(g_grami, vg_grami) for g_grami, vg_grami in zip(G_gram, gram_vg)])
        loss = content_loss + style_loss
        loss.backward(retain_graph = True)
        optimizer.step()
        print(epoch, loss.item())
    sf_content.close()
    [sf.close() for sf in sf_style]
    plt.imshow(transforms.ToPILImage()(G.cpu().detach()[0]))

# %%
showContentChange()
# showStyleChange()
# styleTransfer()
# Out:
# 0 2.3939292430877686
# 1 8.4773530960083
# 2 13.87901782989502
# 3 12.81846809387207
# 4 11.302926063537598
# 5 9.868144989013672
# 6 8.8137788772583
# 7 7.631332874298096
# 8 7.024397373199463
# 9 6.102792739868164
# 10 5.6253981590271
# 11 4.973951816558838
# 12 4.718733787536621
# 13 4.18911600112915
# 14 3.9109296798706055
# 15 3.600801706314087
# 16 3.3976380825042725
# 17 3.130709171295166
# 18 2.965589761734009
# 19 2.8094165325164795
# 20 2.7158353328704834
# 21 2.6095468997955322
# 22 2.5378503799438477
# 23 2.436990976333618
# 24 2.372772455215454
# 25 2.326859474182129
# 26 2.271238088607788
# 27 2.2324249744415283
# 28 2.195655584335327
# 29 2.191202163696289
# 30 2.173332691192627
# 31 2.1923770904541016
# 32 2.2251808643341064
# 33 2.229346513748169
# 34 2.1911282539367676
# 35 2.1397030353546143
# 36 2.1104965209960938
# 37 2.1038684844970703
# 38 2.057006597518921
# 39 2.0479726791381836
# 40 2.062690019607544
# 41 2.0020010471343994
# 42 1.9767112731933594
# ...
